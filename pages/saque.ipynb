# %%
import pandas as pd

# %%
# Ruta absoluta con barras dobles
df = pd.read_excel("C:\\Users\\Betovoley\\Videos\\Master en Python 1 edicion\\Modulo 8\\Tarea M8\\MDPA_TM8\\data\\saque_season_2425.xlsx")

# Mostrar las primeras filas para verificar
print(df.head())
# Out:
#      torneo      fecha  team  rival Fundamento          player  Ind  \
# 0  amistoso 2024-08-22  Sada  Minas      Saque          Equipo    4
# 1  amistoso 2024-08-22  Sada  Minas      Saque    1 Oppenkoski    4
# 2  amistoso 2024-08-22  Sada  Minas      Saque      5 Brasilia    4
# 3  amistoso 2024-08-22  Sada  Minas      Saque       8 Wallace    4
# 4  amistoso 2024-08-22  Sada  Minas      Saque  10 Cledenilson    3
#
#    eficiencia  total_saque  saque=  ...  saque/  saque/dis  saque-  saque-dis  \
# 0        0.10          103    17.0  ...     5.0       0.05    45.0       0.44
# 1        0.12            8     1.0  ...     NaN        NaN     4.0       0.50
# 2        0.25            8     NaN  ...     NaN        NaN     4.0       0.50
# 3        0.20           10     NaN  ...     NaN        NaN     6.0       0.60
# 4        0.00           14     4.0  ...     1.0       0.07     4.0       0.29
#
#    saque!  saque!dis  saque+  saque+dis  saque#  saque#dis
# ...

# %%
df
# Out:
#       torneo      fecha   team  rival Fundamento          player  Ind  \
# 0   amistoso 2024-08-22   Sada  Minas      Saque          Equipo    4
# 1   amistoso 2024-08-22   Sada  Minas      Saque    1 Oppenkoski    4
# 2   amistoso 2024-08-22   Sada  Minas      Saque      5 Brasilia    4
# 3   amistoso 2024-08-22   Sada  Minas      Saque       8 Wallace    4
# 4   amistoso 2024-08-22   Sada  Minas      Saque  10 Cledenilson    3
# 5   amistoso 2024-08-22   Sada  Minas      Saque  11 Rodriguinho    5
# 6   amistoso 2024-08-22   Sada  Minas      Saque      12 Rodrigo    4
# 7   amistoso 2024-08-22   Sada  Minas      Saque      15 Vaccari    4
# 8   amistoso 2024-08-22   Sada  Minas      Saque        16 Lucao    3
# 9   amistoso 2024-08-22   Sada  Minas      Saque        20 Parra    3
# 10  amistoso 2024-08-22   Sada  Minas      Saque       21 Martos    4
# 11  amistoso 2024-08-22   Sada  Minas      Saque      22 Velasco    2
# ...
